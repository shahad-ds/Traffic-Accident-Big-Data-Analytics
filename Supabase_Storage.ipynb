# %%
# !pip install supabase -q

from supabase import create_client

# اتصل بـ Supabase
url = "https://uhqpnyjeieslhbexfbdn.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InVocXBueWplaWVzbGhiZXhmYmRuIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4ODAwNzcsImV4cCI6MjA5MjQ1NjA3N30.i6F8YMXnePXh15IjHRMRo7SlkpmZbmw8FZ2ar47zQO4"

supabase = create_client(url, key)

# ارفع الملف الخام
with open("/content/traffic_accidents.csv", "rb") as f:
    supabase.storage.from_("raw_traffic_accidents").upload("/content/traffic_accidents.csv", f)

print("✅ تم رفع الملف الخام!")
# Out:
# ✅ تم رفع الملف الخام!
